# %% [markdown]
# ##### 마크다운
# #### 마크다운
# ### 마크다운
# ## 마크다운
# # 마크다운
# - 이미지나 표 등 <b>다양한 형태로 메모</b>하고자 할 때 사용
# - 프로그래밍 상에 영향을 주진 않음!

# %% [markdown]
# ### 주피터 노트북 셀 구조
# - 마크다운
# - 에딧셀
#   - 커맨드모드 : 셀 조작 모드
#   - 에딧모드 : 셀에 코드를 입력하는 모드

# %% [markdown]
# #### 커맨드 모드 단축키
# - Enter : 에딧모드로 전환
# - a, b : 위로 셀 추가, 아래로 셀 추가
# - m, [1,2,3,4,5] : 마크다운 셀로 전환 -> y : 에딧 셀로 전환
# - dd, x : 셀 삭제 (⓿_⓿) <b>주의 : 복구 불가(Ctrl + z)</b>!!!
#
# #### 에딧 모드 단축키
# - ESC : 커맨드모드로 전환
#
# ##### 실행 단축키
# - Ctrl + Enter : 제자리에서 실행
# - Shift + Enter : 현재 셀 실행 후 다음 셀로 이동
# - Alt + Enter : 현재 셀 실행후 다음 셀을 추가(삽입)

# %% [markdown]
# #### 변수
# - 사전적 의미 : 변할 수 잇는, 변화를 줄 수 있는 수
# - 프로그래밍 의미 : 데이터를 담을 수 있는 공간(박스)

# %%
num1 = 3
str2 = "7"

str(num1) + str2
# Out:
# '37'

# %%
num1 + int(str2)

# 형변환(castring) : 자료형을 바꾸는 것
# Out:
# 10

# %%
type(num1) # 어떤 자료형인지 확인
# 동적자료형 : 변수의 실행단계에서 자료형이 정해지는 구조
# Out:
# int

# %% [markdown]
# ![image.png](attachment:e0396c50-796a-41c4-9037-d66cf84d2923.png)

# %% [markdown]
# ### 변수명 규칙
# - 숫자로 시작할 수 없음
# - 예약어(키워드) 사용불가!
# - 특수문자 사용 불가능
# - 영문자, 문자+숫자, "_"(언더바)만 사용 가능!(대, 소문자 구분)

# %%
1 = "A"
# Out:
#   Cell In[17], line 1
#     1 = "A"
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
if = "a"
# Out:
#   Cell In[18], line 1
#     if = "a"
#        ^
# SyntaxError: invalid syntax

# %%
import keyword # python에서 제공되는 예약어 확인하는 도구!
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
# 변수명 권장사항 : 개발자들끼리 약속하여 정해둔 규칙
# 1. 소문자로 시작(변수명의 첫글자는 항상 소문자!)
# 2. 두 가지 단어를 섞어서 변수명을 지을 경우, 두 단어를 구분할 수 있게 작성 -> 표기법

number_list # 스네이크 표기법
numberList # 카멜 표기법
# NumberList # 파스칼 표기법

# %%
# 파이썬의 특별한 변수 대입 방법
num1 = 10
num2 = 20
num1,num2 = 10,20

# %%
num1 = 10 
num2 = 10
num1 = num2 = 10

# %%
# 변수 x에는 100을 대입, 변수 y에는 200을 대입
# 변수 sum에는 두 변수의 합을 출력하라!

x = 100
y = 200 
add = x + y 

add
# Out:
# 300

# %%
sum([1,2,3])
# Out:
# 6

# %% [markdown]
# ### 문자열 다루기

# %%
s =  "she's gone"
s
# Out:
# "she's gone"

# %%
# 이스케이프 코드 : 이미 약속된 문자열 조합

s = 'she\'s gone'

# %% [markdown]
# ![image.png](attachment:26749e19-e2e3-4b30-8a6c-69eb1e9a2c01.png)

# %%
s = "자세히 보아야 이쁘다. \n오래보아야 사랑스럽다."
print(s, end ="\t")
print(s)
# Out:
# 자세히 보아야 이쁘다.
# 오래보아야 사랑스럽다.	자세히 보아야 이쁘다.
# 오래보아야 사랑스럽다.

# %%
print(s)
# Out:
# 자세히 보아야 이쁘다.
# 오래보아야 사랑스럽다.

# %%
# 긴줄문자열기호: """""",''''''
s = """자세히 보아야 이쁘다.
오래보아야 사랑스럽다."""

print(s)
# Out:
# '자세히 보아야 이쁘다.\n오래보아야 사랑스럽다.'

# %% [markdown]
# #### 문자열 인덱싱, 슬라이싱
# - 인덱스(index) : 순서가 있는 데이터가 생성될 때 자동으로 부여되는 번호(방 번호)
# - 인덱싱(indexing) : 무엇인가를 가리킨다는 의미
# - 슬라이싱(slicing) : 무엇인가를 잘라낸다는 의미

# %% [markdown]
# ### 문자열 포매팅
# - 문자열 안에 특정한 값을 수정해야 될 때 사용
# 1. 포캣코드 활용
# 2. format() 활용
# 3. f문자열 포매팅

# %%
# 1. 포맷코드
month = 6
day = 20

s = "오늘은 %d월 %d일 입니다."%(month, day)
s
# Out:
# '오늘은 6월 20일 입니다.'

# %% [markdown]
# ![image.png](attachment:30f487cd-095f-442f-9a1f-ebec8cdc0fa4.png)

# %%
# 2. 포맷함수
month = 6
day = 33

s = "오늘은 {}월 {}일 입니다.".format(month, day)
s
# Out:
# '오늘은 6월 33일 입니다.'

# %%
# 3. f문자열 포매팅

month = 9
day = 35

s = f"오늘은 {month}월 {day}일 입니다."
s
# Out:
# '오늘은 9월 35일 입니다.'

# %%
s = "오늘 날씨는 맑음입니다!"
s.replace("!", ".")
# Out:
# '오늘 날씨는 맑음입니다.'

# %% [markdown]
# ### 문자열 함수
# | 함수 | 사용법 | 설명 | 반환값 |
# |------|--------|------|-------|
# | replace | `str.replace(old, new[, count])` | 문자열에서 `old`를 `new`로 대체 | 새 문자열 |
# | upper | `str.upper()` | 문자열의 모든 문자를 대문자로 변환 | 새 문자열 |
# | lower | `str.lower()` | 문자열의 모든 문자를 소문자로 변환 | 새 문자열 |
# | strip | `str.strip([chars])` | 문자열 양쪽 끝의 공백이나 `chars`에 지정된 문자 제거 | 새 문자열 |
# | lstrip | `str.lstrip([chars])` | 문자열 왼쪽 끝의 공백이나 `chars`에 지정된 문자 제거 | 새 문자열 |
# | rstrip | `str.rstrip([chars])` | 문자열 오른쪽 끝의 공백이나 `chars`에 지정된 문자 제거 | 새 문자열 |
# | find | `str.find(sub[, start[, end]])` | 부분 문자열 `sub`이 처음 나타나는 위치 탐색 | 위치 인덱스 또는 -1 |
# | rfind | `str.rfind(sub[, start[, end]])` | 부분 문자열 `sub`이 마지막으로 나타나는 위치 탐색 | 위치 인덱스 또는 -1 |
# | split | `str.split([sep[, maxsplit]])` | `sep`을 기준으로 문자열을 나눔 | 문자열 리스트 |
# | rsplit | `str.rsplit([sep[, maxsplit]])` | `sep`을 기준으로 문자열을 오른쪽에서부터 나눔 | 문자열 리스트 |
# | join | `str.join(iterable)` | `iterable`의 각 요소를 문자열로 연결 | 새 문자열 |
# | count | `str.count(sub[, start[, end]])` | 문자열에서 부분 문자열 `sub`의 출현 횟수 계산 | 정수 |
# | index | `str.index(sub[, start[, end]])` | 부분 문자열 `sub`이 처음 나타나는 위치 탐색(찾지 못하면 예외 발생) | 위치 인덱스 |
# | rindex | `str.rindex(sub[, start[, end]])` | 부분 문자열 `sub`이 마지막으로 나타나는 위치 탐색(찾지 못하면 예외 발생) | 위치 인덱스 |
# | startswith | `str.startswith(prefix[, start[, end]])` | 문자열이 지정된 접두어로 시작하는지 여부 | 불리언 |
# | endswith | `str.endswith(suffix[, start[, end]])` | 문자열이 지정된 접미어로 끝나는지 여부 | 불리언 |
# | isdigit | `str.isdigit()` | 문자열이 숫자로만 구성되어 있는지 여부 | 불리언 |
# | isalpha | `str.isalpha()` | 문자열이 알파벳 문자로만 구성되어 있는지 여부 | 불리언 |
# | isalnum | `str.isalnum()` | 문자열이 알파벳 문자와 숫자로만 구성되어 있는지 여부 | 불리언 |
# | isspace | `str.isspace()` | 문자열이 공백 문자로만 구성되어 있는지 여부 | 불리언 |
# | istitle | `str.istitle()` | 문자열이 타이틀 케이스(각 단어의 첫 글자가 대문자)인지 여부 | 불리언 |
# | capitalize | `str.capitalize()` | 문자열의 첫 글자를 대문자로, 나머지는 소문자로 변환 | 새 문자열 |
# | title | `str.title()` | 각 단어의 첫 글자를 대문자로, 나머지는 소문자로 변환 | 새 문자열 |
# | zfill | `str.zfill(width)` | 문자열의 왼쪽을 '0'으로 채워 지정된 너비에 맞춤 | 새 문자열 |
# | ljust | `str.ljust(width[, fillchar])` | 문자열을 지정된 너비로 왼쪽 정렬 | 새 문자열 |
# | rjust | `str.rjust(width[, fillchar])` | 문자열을 지정된 너비로 오른쪽 정렬 | 새 문자열 |
# | center | `str.center(width[, fillchar])` | 문자열을 지정된 너비로 중앙 정렬 | 새 문자열 |
# | encode | `str.encode(encoding='utf-8', errors='strict')` | 문자열을 지정된 인코딩으로 인코딩 | 바이트 객체 |
# | format | `str.format(*args, **kwargs)` | 문자열의 형식을 지정된 값으로 채움 | 새 문자열 |

# %% [markdown]
# ### 연산자
# ![image.png](attachment:8d112351-caf4-41ab-a377-a0067e22f318.png)

# %%
num1 = 10
num2 = 7

# : .2f -> 소수점 둘째자리까지 출력, 알아서 반올림
print(f"나누기 : {num1 / num2:.3f}") 
print(num1 // num2)
print(num1 % num2)
# Out:
# 나누기 : 1.429
# 1
# 3

# %%
s1 = "하위"
s2 = "하세요"

s1 + s2
# Out:
# '하위하세요'

# %%
s1 * 5
# Out:
# '하위하위하위하위하위'

# %%
# 복합 대입 연산자 : 누적할 때 사용!
num = 27
print(num)

# %%
num += 3
print(num)
# Out:
# 381

# %%
# 논리 연산자 : bool(true, False) 연산
True and True
# Out:
# True

# %% [markdown]
# 5. 논리연산자
#     - and : 두 값이 참인 경우 참(True), 이 외에는 전부 거짓(False)
#     - or : 두 값 중에 하나라도 참인 경우 참(True), 두 값이 거짓인 경우에 거짓(False)
#     - not : 부정
#
# | 값1 | 값2 | 논리연산자 | 연산된 값 |
# |-----|-----|-----------|----------|
# |0|0|and|0|
# |0|1|and|0|
# |1|0|and|0|
# |1|1|and|1|
# |0|0|or|0|
# |0|1|or|1|
# |1|0|or|1|
# |1|1|or|1|
# |0|-|not|1|
# |1|-|not|0|

# %%
# 논리 연산자 : bool(True, False) 연산
True and True
# Out:
# True

# %%
# 논리연산자 : and , or, not -> 단일 값에 대해서 논리연산 수행
# 비트연산자 : &, | -> 다중 값에 대해서 논리연산 수행

import numpy as np

arr1 = np.array([1,2,3,4,5,6,7])
arr1[(arr1 >= 3) & (arr1 <= 5)]
# Out:
# array([3, 4, 5])

# %%
# 멤버연산자
# in : ~~가 들어있니?
# not in : ~~가 들어있지 않니?

s="Life is too short, you need python!"
s
# Out:
# 'Life is too short, you need python!'

# %%
'e' in s
# Out:
# True

# %% [markdown]
# # 삼항연산자 -> 간단한 이진분류
#
# ```python
# a if 조건식 else b
# ```
#
# - 조건식이 True인 경우 a
# - 조건식이 False인 경우 b

# %%
score = 59

"합격" if score >= 60 else "불합격"
# Out:
# '불합격'
